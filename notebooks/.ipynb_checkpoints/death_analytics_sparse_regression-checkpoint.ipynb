# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load Built-in Modules
import pandas as pd
import numpy as np
from datetime import timedelta
import seaborn as sns
import os
import matplotlib.pyplot as plt
import pickle
from ml_war_machine.feature_engineering import feature_engineering as fe
from ml_war_machine.machine_learning import feature_selection as fs
from ml_war_machine.statistical_analysis import statistical_analysis as statistical_analysis

# Ignore Python package warnings (not verbose)
import warnings
warnings.filterwarnings("ignore")

# %%
# paths
DIRECTORY_PATH = os.path.dirname(os.getcwd())
os.chdir(DIRECTORY_PATH)

DATA_PATH   = os.path.join(os.getcwd(), "data", "input")
RESULT_PATH = os.path.join(os.path.dirname(os.getcwd()), "results")
MODEL_PATH  = os.path.join(os.getcwd(), "models")
target = "deaths"

# %%
# experiment name
EXPERIMENT_FOLDER = "02 - Data Analysis"
try: 
    assert os.path.exists(os.path.join(RESULT_PATH, EXPERIMENT_FOLDER))
except AssertionError:
    os.makedirs(os.path.join(RESULT_PATH, EXPERIMENT_FOLDER))

# %%
file = '06_29_2020_states_combined.csv'
df = pd.read_csv(os.path.join(DATA_PATH, file), parse_dates=["date"], index_col=[0])

# Exception
df = df[df["state"]!='Guam']
df = df[df["state"]!='Northern Mariana Islands']
df = df[df["state"]!='Puerto Rico']
df = df[df["state"]!='Diamond Princess']
df = df[df["state"]!='Grand Princess']
df = df[df["state"]!='American Samoa']
df = df[df["state"]!='Virgin Islands']

df.sort_values(["state", "date"], inplace=True)

# %%
df.head()
# Out:
#      state       date  cases  deaths  population  emergdec  schoolclose  \
# 0  Alabama 2020-01-22      0       0   4903185.0         0            0
# 1  Alabama 2020-01-23      0       0   4903185.0         0            0
# 2  Alabama 2020-01-24      0       0   4903185.0         0            0
# 3  Alabama 2020-01-25      0       0   4903185.0         0            0
# 4  Alabama 2020-01-26      0       0   4903185.0         0            0
#
#    gathrestrict25  gathrestrictany  otherbusinessclose  ...  workplaces  \
# 0               0                0                   0  ...         NaN
# 1               0                0                   0  ...         NaN
# 2               0                0                   0  ...         NaN
# 3               0                0                   0  ...         NaN
# 4               0                0                   0  ...         NaN
#
#    residential  recovered  active  incident_rate  people_tested  \
# 0          NaN        NaN     NaN            NaN            NaN
# 1          NaN        NaN     NaN            NaN            NaN
# 2          NaN        NaN     NaN            NaN            NaN
# 3          NaN        NaN     NaN            NaN            NaN
# 4          NaN        NaN     NaN            NaN            NaN
#
#    people_hospitalized  mortality_rate  testing_rate  hospitalization_rate
# 0                  NaN             NaN           NaN                   NaN
# 1                  NaN             NaN           NaN                   NaN
# 2                  NaN             NaN           NaN                   NaN
# 3                  NaN             NaN           NaN                   NaN
# 4                  NaN             NaN           NaN                   NaN
#
# [5 rows x 42 columns]

# %%
df["cases_nom"] = df["cases"] / df["population"]
df["deaths_nom"] = df["deaths"] / df["population"]

# %%
for columns in df.columns :
    print("column name : {} - {} NaN".format(columns, df[columns].isnull().mean()))
    
print(df.isnull().mean().mean())
# Out:
# column name : state - 0.0 NaN
# column name : date - 0.0 NaN
# column name : cases - 0.0 NaN
# column name : deaths - 0.0 NaN
# column name : population - 0.0 NaN
# column name : emergdec - 0.0 NaN
# column name : schoolclose - 0.0 NaN
# column name : gathrestrict25 - 0.0 NaN
# column name : gathrestrictany - 0.0 NaN
# column name : otherbusinessclose - 0.0 NaN
# column name : restaurantrestrict - 0.0 NaN
# column name : gathrestrict10 - 0.0 NaN
# column name : caseisolation - 0.0 NaN
# column name : stayathome - 0.0 NaN
# column name : publicmask - 0.0 NaN
# column name : quarantine - 0.0 NaN
# column name : nebusinessclose - 0.0 NaN
# column name : travelrestrictintra - 0.0 NaN
# column name : gathrestrict50 - 0.0 NaN
# column name : gathrecomany - 0.0 NaN
# column name : gathrestrict250 - 0.0 NaN
# column name : gathrestrict5 - 0.0 NaN
# column name : gathrestrict100 - 0.0 NaN
# column name : gathrestrict1000 - 0.0 NaN
# column name : gathrestrict3 - 0.0 NaN
# column name : travelrestrictexit - 0.0 NaN
# column name : travelrestrictentry - 0.0 NaN
# column name : gathrestrict500 - 0.0 NaN
# column name : retail_and_recreation - 0.17721518987341772 NaN
# column name : grocery_and_pharmacy - 0.17721518987341772 NaN
# column name : parks - 0.18019359642591215 NaN
# column name : transit_stations - 0.17721518987341772 NaN
# column name : workplaces - 0.17721518987341772 NaN
# column name : residential - 0.17721518987341772 NaN
# column name : recovered - 0.6279473814842392 NaN
# column name : active - 0.5126582278481012 NaN
# column name : incident_rate - 0.5126582278481012 NaN
# column name : people_tested - 0.5126582278481012 NaN
# column name : people_hospitalized - 0.6443286175229586 NaN
# column name : mortality_rate - 0.5126582278481012 NaN
# column name : testing_rate - 0.5126582278481012 NaN
# column name : hospitalization_rate - 0.6443286175229586 NaN
# column name : cases_nom - 0.0 NaN
# column name : deaths_nom - 0.0 NaN
# 0.12604921139917416

# %%
df = df.loc[:, df.isnull().mean() < 0.25]
df.shape
# Out:
# (8058, 36)

# %%
col_to_keep = set(df.columns.tolist())

# %%
df.columns.tolist()
# Out:
# ['state',
#  'date',
#  'cases',
#  'deaths',
#  'population',
#  'emergdec',
#  'schoolclose',
#  'gathrestrict25',
#  'gathrestrictany',
#  'otherbusinessclose',
#  'restaurantrestrict',
#  'gathrestrict10',
#  'caseisolation',
#  'stayathome',
#  'publicmask',
#  'quarantine',
#  'nebusinessclose',
#  'travelrestrictintra',
#  'gathrestrict50',
#  'gathrecomany',
#  'gathrestrict250',
#  'gathrestrict5',
#  'gathrestrict100',
#  'gathrestrict1000',
#  'gathrestrict3',
#  'travelrestrictexit',
#  'travelrestrictentry',
#  'gathrestrict500',
#  'retail_and_recreation',
#  'grocery_and_pharmacy',
#  'parks',
#  'transit_stations',
#  'workplaces',
#  'residential',
#  'cases_nom',
#  'deaths_nom']

# %%
col_to_diff = set([
    # 'emergdec', # bool
    # 'schoolclose', # bool
    # 'gathrestrict25', # bool
    # 'gathrestrictany', # bool
    # 'otherbusinessclose' # bool # interesting,
    # 'restaurantrestrict',  # bool
    # 'gathrestrict10',  # bool # gathrestrict10
    # 'caseisolation',  # bool
    # 'stayathome',  # bool  # interesting
    # 'publicmask',  # bool # interesting
    # 'quarantine',  # bool # interesting
    # 'nebusinessclose',  # bool # interesting
    # 'travelrestrictintra',  # bool # interesting
    # 'gathrestrict50',  # bool # interesting
    # 'gathrecomany',
    # 'gathrestrict250',
    # 'gathrestrict5',
    # 'gathrestrict1000',
    # 'gathrestrict100',
    # 'gathrestrict3',
    # 'travelrestrictexit',
    # 'travelrestrictentry',
    # 'gathrestrict500',
    'retail_and_recreation',
    'grocery_and_pharmacy',
    'parks',
    'transit_stations',
    'workplaces',  # seasonality?
    'residential',  # seasonality
    
    # #### start too late
    # 'recovered',  
    # 'active',  # start too late
    # 'incident_rate',
    # 'people_tested',
    # 'people_hospitalized',
    # 'mortality_rate',
    # 'testing_rate',
    # 'hospitalization_rate',
    'home_time',
    'percentage',
    'full_time',
    'part_time',
    'non_home_time',
    'distance', 
    'cases_nom',
    'deaths_nom'
    ])

col_to_diff = col_to_diff & col_to_keep

# add differences
df_ = fe.pct(df, col_to_diff, index='state', lags=(1, 2, 5, 10))

# %%
col_to_pct = set([
    'deaths',
    'cases',
    'retail_and_recreation',
    'grocery_and_pharmacy',
    'parks',
    'transit_stations',
    'workplaces',  # seasonality?
    'residential',  # seasonality
    'home_time',
    'percentage',
    'full_time',
    'part_time',
    'non_home_time',
    'distance', 
    'cases_nom',
    'deaths_nom'
    ])

col_to_pct = col_to_pct & col_to_keep

# add percentage changes
df = fe.pct(df, col_to_pct, index='state', lags=(1, 2, 5, 10))

# %%
col_to_ma = set([
    'retail_and_recreation',
    'grocery_and_pharmacy',
    'parks',
    'transit_stations',
    'workplaces',  # seasonality?
    'residential',  # seasonality
    'home_time',
    'percentage',
    'full_time',
    'part_time',
    'non_home_time',
    'distance', 
    'cases_nom',
    'deaths_nom'
    ])

col_to_ma = col_to_ma & col_to_keep
# add pct
col_to_ma = set([col+ "_pct1" for col in col_to_ma])

# add moving average
df = fe.ma_mean(df, col_to_ma, index='state', periods=(1, 2, 7, 10))

# %%
col_to_lag = set(df.columns) - {'state', 'date', 'population'}
df = fe.lag(df, col_to_lag, index='state', nb_lag=5)
# Out:
# 365it [00:24, 15.12it/s]

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
# df = df.loc[:, df.isnull().mean() < 0.1]
df.shape
# Out:
# (8058, 441)

# %%
for columns in df.columns :
    print("column name : {} - {} NaN".format(columns, df[columns].isnull().mean()))
    
print(df.isnull().mean().mean())
# Out:
# column name : state - 0.0 NaN
# column name : date - 0.0 NaN
# column name : cases - 0.0 NaN
# column name : deaths - 0.0 NaN
# column name : population - 0.0 NaN
# column name : emergdec - 0.0 NaN
# column name : schoolclose - 0.0 NaN
# column name : gathrestrict25 - 0.0 NaN
# column name : gathrestrictany - 0.0 NaN
# column name : otherbusinessclose - 0.0 NaN
# column name : restaurantrestrict - 0.0 NaN
# column name : gathrestrict10 - 0.0 NaN
# column name : caseisolation - 0.0 NaN
# column name : stayathome - 0.0 NaN
# column name : publicmask - 0.0 NaN
# column name : quarantine - 0.0 NaN
# column name : nebusinessclose - 0.0 NaN
# column name : travelrestrictintra - 0.0 NaN
# column name : gathrestrict50 - 0.0 NaN
# column name : gathrecomany - 0.0 NaN
# column name : gathrestrict250 - 0.0 NaN
# column name : gathrestrict5 - 0.0 NaN
# column name : gathrestrict100 - 0.0 NaN
# column name : gathrestrict1000 - 0.0 NaN
# column name : gathrestrict3 - 0.0 NaN
# column name : travelrestrictexit - 0.0 NaN
# column name : travelrestrictentry - 0.0 NaN
# column name : gathrestrict500 - 0.0 NaN
# column name : retail_and_recreation - 0.17721518987341772 NaN
# column name : grocery_and_pharmacy - 0.17721518987341772 NaN
# column name : parks - 0.18019359642591215 NaN
# column name : transit_stations - 0.17721518987341772 NaN
# column name : workplaces - 0.17721518987341772 NaN
# column name : residential - 0.17721518987341772 NaN
# column name : cases_nom - 0.0 NaN
# column name : deaths_nom - 0.0 NaN
# column name : transit_stations_pct1 - 0.17436088359394392 NaN
# column name : retail_and_recreation_pct1 - 0.1700173740382229 NaN
# column name : workplaces_pct1 - 0.1747331844130057 NaN
# column name : deaths_nom_pct1 - 0.37031521469347234 NaN
# column name : parks_pct1 - 0.16679076693968728 NaN
# column name : grocery_and_pharmacy_pct1 - 0.1907421196326632 NaN
# column name : cases_nom_pct1 - 0.2722759990071978 NaN
# column name : residential_pct1 - 0.21891288160833955 NaN
# column name : transit_stations_pct2 - 0.18044179697195334 NaN
# column name : retail_and_recreation_pct2 - 0.17609828741623232 NaN
# column name : workplaces_pct2 - 0.18106229833705634 NaN
# column name : deaths_nom_pct2 - 0.37664432861752295 NaN
# column name : parks_pct2 - 0.1729957805907173 NaN
# column name : grocery_and_pharmacy_pct2 - 0.19669893273765202 NaN
# column name : cases_nom_pct2 - 0.27860511293124846 NaN
# column name : residential_pct2 - 0.22524199553239016 NaN
# column name : transit_stations_pct5 - 0.19868453710598163 NaN
# column name : retail_and_recreation_pct5 - 0.19434102755026061 NaN
# column name : workplaces_pct5 - 0.20004964010920823 NaN
# column name : deaths_nom_pct5 - 0.39563167038967484 NaN
# column name : parks_pct5 - 0.1916108215438074 NaN
# column name : grocery_and_pharmacy_pct5 - 0.21456937205261853 NaN
# column name : cases_nom_pct5 - 0.29759245470340034 NaN
# column name : residential_pct5 - 0.24422933730454208 NaN
# column name : transit_stations_pct10 - 0.2297096053611318 NaN
# column name : retail_and_recreation_pct10 - 0.22549019607843138 NaN
# column name : workplaces_pct10 - 0.2316952097294614 NaN
# column name : deaths_nom_pct10 - 0.427277240009928 NaN
# column name : parks_pct10 - 0.22325639116406057 NaN
# column name : grocery_and_pharmacy_pct10 - 0.24422933730454208 NaN
# column name : cases_nom_pct10 - 0.3292380243236535 NaN
# column name : residential_pct10 - 0.27438570364854803 NaN
# column name : deaths_pct1 - 0.37031521469347234 NaN
# column name : cases_pct1 - 0.2722759990071978 NaN
# column name : deaths_pct2 - 0.37664432861752295 NaN
# column name : cases_pct2 - 0.27860511293124846 NaN
# column name : deaths_pct5 - 0.39563167038967484 NaN
# column name : cases_pct5 - 0.29759245470340034 NaN
# column name : deaths_pct10 - 0.427277240009928 NaN
# column name : cases_pct10 - 0.3292380243236535 NaN
# column name : deaths_nom_pct2_lag1 - 0.3829734425415736 NaN
# column name : deaths_nom_pct2_lag2 - 0.3893025564656242 NaN
# column name : deaths_nom_pct2_lag3 - 0.39563167038967484 NaN
# column name : deaths_nom_pct2_lag4 - 0.4019607843137255 NaN
# column name : deaths_nom_pct2_lag5 - 0.4082898982377761 NaN
# column name : grocery_and_pharmacy_pct1_lag1 - 0.19694713328369323 NaN
# column name : grocery_and_pharmacy_pct1_lag2 - 0.20277984611566147 NaN
# column name : grocery_and_pharmacy_pct1_lag3 - 0.2087366592206503 NaN
# column name : grocery_and_pharmacy_pct1_lag4 - 0.21456937205261853 NaN
# column name : grocery_and_pharmacy_pct1_lag5 - 0.22065028543062795 NaN
# column name : otherbusinessclose_lag1 - 0.006329113924050633 NaN
# column name : otherbusinessclose_lag2 - 0.012658227848101266 NaN
# column name : otherbusinessclose_lag3 - 0.0189873417721519 NaN
# column name : otherbusinessclose_lag4 - 0.02531645569620253 NaN
# column name : otherbusinessclose_lag5 - 0.03164556962025317 NaN
# column name : workplaces_pct5_lag1 - 0.20637875403325887 NaN
# column name : workplaces_pct5_lag2 - 0.2127078679573095 NaN
# column name : workplaces_pct5_lag3 - 0.21903698188136014 NaN
# column name : workplaces_pct5_lag4 - 0.22536609580541078 NaN
# column name : workplaces_pct5_lag5 - 0.2316952097294614 NaN
# column name : retail_and_recreation_pct1_lag1 - 0.1763464879622735 NaN
# column name : retail_and_recreation_pct1_lag2 - 0.18242740134028296 NaN
# column name : retail_and_recreation_pct1_lag3 - 0.18863241499131297 NaN
# column name : retail_and_recreation_pct1_lag4 - 0.1945892280963018 NaN
# column name : retail_and_recreation_pct1_lag5 - 0.20079424174733185 NaN
# column name : publicmask_lag1 - 0.006329113924050633 NaN
# column name : publicmask_lag2 - 0.012658227848101266 NaN
# column name : publicmask_lag3 - 0.0189873417721519 NaN
# column name : publicmask_lag4 - 0.02531645569620253 NaN
# column name : publicmask_lag5 - 0.03164556962025317 NaN
# column name : cases_nom_lag1 - 0.006329113924050633 NaN
# column name : cases_nom_lag2 - 0.012658227848101266 NaN
# column name : cases_nom_lag3 - 0.0189873417721519 NaN
# column name : cases_nom_lag4 - 0.02531645569620253 NaN
# column name : cases_nom_lag5 - 0.03164556962025317 NaN
# column name : deaths_pct1_lag1 - 0.37664432861752295 NaN
# column name : deaths_pct1_lag2 - 0.3829734425415736 NaN
# column name : deaths_pct1_lag3 - 0.3893025564656242 NaN
# column name : deaths_pct1_lag4 - 0.39563167038967484 NaN
# column name : deaths_pct1_lag5 - 0.4019607843137255 NaN
# column name : stayathome_lag1 - 0.006329113924050633 NaN
# column name : stayathome_lag2 - 0.012658227848101266 NaN
# column name : stayathome_lag3 - 0.0189873417721519 NaN
# column name : stayathome_lag4 - 0.02531645569620253 NaN
# column name : stayathome_lag5 - 0.03164556962025317 NaN
# column name : retail_and_recreation_pct5_lag1 - 0.20054604120129063 NaN
# column name : retail_and_recreation_pct5_lag2 - 0.20675105485232068 NaN
# column name : retail_and_recreation_pct5_lag3 - 0.21308016877637131 NaN
# column name : retail_and_recreation_pct5_lag4 - 0.21940928270042195 NaN
# column name : retail_and_recreation_pct5_lag5 - 0.22573839662447256 NaN
# column name : transit_stations_lag1 - 0.18168279970215934 NaN
# column name : transit_stations_lag2 - 0.18428890543559195 NaN
# column name : transit_stations_lag3 - 0.18801191362620998 NaN
# column name : transit_stations_lag4 - 0.1906180193596426 NaN
# column name : transit_stations_lag5 - 0.19583023082650783 NaN
# column name : gathrestrict1000_lag1 - 0.006329113924050633 NaN
# column name : gathrestrict1000_lag2 - 0.012658227848101266 NaN
# column name : gathrestrict1000_lag3 - 0.0189873417721519 NaN
# column name : gathrestrict1000_lag4 - 0.02531645569620253 NaN
# column name : gathrestrict1000_lag5 - 0.03164556962025317 NaN
# column name : parks_lag1 - 0.18453710598163317 NaN
# column name : parks_lag2 - 0.18714321171506576 NaN
# column name : parks_lag3 - 0.19086621990568378 NaN
# column name : parks_lag4 - 0.1934723256391164 NaN
# column name : parks_lag5 - 0.19868453710598163 NaN
# column name : gathrestrict500_lag1 - 0.006329113924050633 NaN
# column name : gathrestrict500_lag2 - 0.012658227848101266 NaN
# column name : gathrestrict500_lag3 - 0.0189873417721519 NaN
# column name : gathrestrict500_lag4 - 0.02531645569620253 NaN
# column name : gathrestrict500_lag5 - 0.03164556962025317 NaN
# column name : deaths_nom_pct1_lag1 - 0.37664432861752295 NaN
# column name : deaths_nom_pct1_lag2 - 0.3829734425415736 NaN
# column name : deaths_nom_pct1_lag3 - 0.3893025564656242 NaN
# column name : deaths_nom_pct1_lag4 - 0.39563167038967484 NaN
# column name : deaths_nom_pct1_lag5 - 0.4019607843137255 NaN
# column name : quarantine_lag1 - 0.006329113924050633 NaN
# column name : quarantine_lag2 - 0.012658227848101266 NaN
# column name : quarantine_lag3 - 0.0189873417721519 NaN
# column name : quarantine_lag4 - 0.02531645569620253 NaN
# column name : quarantine_lag5 - 0.03164556962025317 NaN
# column name : parks_pct10_lag1 - 0.22946140481509059 NaN
# column name : parks_pct10_lag2 - 0.23579051873914122 NaN
# column name : parks_pct10_lag3 - 0.24211963266319186 NaN
# column name : parks_pct10_lag4 - 0.2484487465872425 NaN
# column name : parks_pct10_lag5 - 0.25477786051129314 NaN
# column name : nebusinessclose_lag1 - 0.006329113924050633 NaN
# column name : nebusinessclose_lag2 - 0.012658227848101266 NaN
# column name : nebusinessclose_lag3 - 0.0189873417721519 NaN
# column name : nebusinessclose_lag4 - 0.02531645569620253 NaN
# column name : nebusinessclose_lag5 - 0.03164556962025317 NaN
# column name : gathrestrictany_lag1 - 0.006329113924050633 NaN
# column name : gathrestrictany_lag2 - 0.012658227848101266 NaN
# column name : gathrestrictany_lag3 - 0.0189873417721519 NaN
# column name : gathrestrictany_lag4 - 0.02531645569620253 NaN
# column name : gathrestrictany_lag5 - 0.03164556962025317 NaN
# column name : deaths_nom_pct10_lag1 - 0.43360635393397867 NaN
# column name : deaths_nom_pct10_lag2 - 0.4399354678580293 NaN
# column name : deaths_nom_pct10_lag3 - 0.4462645817820799 NaN
# column name : deaths_nom_pct10_lag4 - 0.45259369570613056 NaN
# column name : deaths_nom_pct10_lag5 - 0.45892280963018117 NaN
# column name : residential_pct10_lag1 - 0.2805907172995781 NaN
# column name : residential_pct10_lag2 - 0.2867957309506081 NaN
# column name : residential_pct10_lag3 - 0.29312484487465873 NaN
# column name : residential_pct10_lag4 - 0.2987093571605858 NaN
# column name : residential_pct10_lag5 - 0.3046661702655746 NaN
# column name : cases_nom_pct2_lag1 - 0.28493422685529907 NaN
# column name : cases_nom_pct2_lag2 - 0.29126334077934973 NaN
# column name : cases_nom_pct2_lag3 - 0.29759245470340034 NaN
# column name : cases_nom_pct2_lag4 - 0.30392156862745096 NaN
# column name : cases_nom_pct2_lag5 - 0.3102506825515016 NaN
# column name : residential_pct1_lag1 - 0.22499379498634897 NaN
# column name : residential_pct1_lag2 - 0.2313229089103996 NaN
# column name : residential_pct1_lag3 - 0.23765202283445025 NaN
# column name : residential_pct1_lag4 - 0.24385703648548027 NaN
# column name : residential_pct1_lag5 - 0.2501861504095309 NaN
# column name : workplaces_pct2_lag1 - 0.18739141226110698 NaN
# column name : workplaces_pct2_lag2 - 0.19372052618515762 NaN
# column name : workplaces_pct2_lag3 - 0.20004964010920823 NaN
# column name : workplaces_pct2_lag4 - 0.20637875403325887 NaN
# column name : workplaces_pct2_lag5 - 0.2127078679573095 NaN
# column name : cases_pct2_lag1 - 0.28493422685529907 NaN
# column name : cases_pct2_lag2 - 0.29126334077934973 NaN
# column name : cases_pct2_lag3 - 0.29759245470340034 NaN
# column name : cases_pct2_lag4 - 0.30392156862745096 NaN
# column name : cases_pct2_lag5 - 0.3102506825515016 NaN
# column name : grocery_and_pharmacy_pct5_lag1 - 0.22040208488458674 NaN
# column name : grocery_and_pharmacy_pct5_lag2 - 0.22635889798957556 NaN
# column name : grocery_and_pharmacy_pct5_lag3 - 0.23243981136758501 NaN
# column name : grocery_and_pharmacy_pct5_lag4 - 0.23852072474559444 NaN
# column name : grocery_and_pharmacy_pct5_lag5 - 0.24472573839662448 NaN
# column name : deaths_nom_lag1 - 0.006329113924050633 NaN
# column name : deaths_nom_lag2 - 0.012658227848101266 NaN
# column name : deaths_nom_lag3 - 0.0189873417721519 NaN
# column name : deaths_nom_lag4 - 0.02531645569620253 NaN
# column name : deaths_nom_lag5 - 0.03164556962025317 NaN
# column name : parks_pct1_lag1 - 0.1728716803176967 NaN
# column name : parks_pct1_lag2 - 0.17920079424174734 NaN
# column name : parks_pct1_lag3 - 0.18552990816579795 NaN
# column name : parks_pct1_lag4 - 0.1918590220898486 NaN
# column name : parks_pct1_lag5 - 0.19806403574087864 NaN
# column name : schoolclose_lag1 - 0.006329113924050633 NaN
# column name : schoolclose_lag2 - 0.012658227848101266 NaN
# column name : schoolclose_lag3 - 0.0189873417721519 NaN
# column name : schoolclose_lag4 - 0.02531645569620253 NaN
# column name : schoolclose_lag5 - 0.03164556962025317 NaN
# column name : transit_stations_pct2_lag1 - 0.18677091089600398 NaN
# column name : transit_stations_pct2_lag2 - 0.1928518242740134 NaN
# column name : transit_stations_pct2_lag3 - 0.19918093819806404 NaN
# column name : transit_stations_pct2_lag4 - 0.20513775130305287 NaN
# column name : transit_stations_pct2_lag5 - 0.2113427649540829 NaN
# column name : parks_pct5_lag1 - 0.19793993546785804 NaN
# column name : parks_pct5_lag2 - 0.20426904939190865 NaN
# column name : parks_pct5_lag3 - 0.2104740630429387 NaN
# column name : parks_pct5_lag4 - 0.21680317696698934 NaN
# column name : parks_pct5_lag5 - 0.22313229089103995 NaN
# column name : travelrestrictentry_lag1 - 0.006329113924050633 NaN
# column name : travelrestrictentry_lag2 - 0.012658227848101266 NaN
# column name : travelrestrictentry_lag3 - 0.0189873417721519 NaN
# column name : travelrestrictentry_lag4 - 0.02531645569620253 NaN
# column name : travelrestrictentry_lag5 - 0.03164556962025317 NaN
# column name : workplaces_pct10_lag1 - 0.23802432365351203 NaN
# column name : workplaces_pct10_lag2 - 0.24435343757756267 NaN
# column name : workplaces_pct10_lag3 - 0.2506825515016133 NaN
# column name : workplaces_pct10_lag4 - 0.25701166542566395 NaN
# column name : workplaces_pct10_lag5 - 0.26334077934971456 NaN
# column name : gathrestrict10_lag1 - 0.006329113924050633 NaN
# column name : gathrestrict10_lag2 - 0.012658227848101266 NaN
# column name : gathrestrict10_lag3 - 0.0189873417721519 NaN
# column name : gathrestrict10_lag4 - 0.02531645569620253 NaN
# column name : gathrestrict10_lag5 - 0.03164556962025317 NaN
# column name : grocery_and_pharmacy_pct2_lag1 - 0.20265574584264084 NaN
# column name : grocery_and_pharmacy_pct2_lag2 - 0.20848845867460908 NaN
# column name : grocery_and_pharmacy_pct2_lag3 - 0.2143211715065773 NaN
# column name : grocery_and_pharmacy_pct2_lag4 - 0.21990568379250433 NaN
# column name : grocery_and_pharmacy_pct2_lag5 - 0.2258624968974932 NaN
# column name : gathrestrict100_lag1 - 0.006329113924050633 NaN
# column name : gathrestrict100_lag2 - 0.012658227848101266 NaN
# column name : gathrestrict100_lag3 - 0.0189873417721519 NaN
# column name : gathrestrict100_lag4 - 0.02531645569620253 NaN
# column name : gathrestrict100_lag5 - 0.03164556962025317 NaN
# column name : workplaces_lag1 - 0.18168279970215934 NaN
# column name : workplaces_lag2 - 0.18428890543559195 NaN
# column name : workplaces_lag3 - 0.18801191362620998 NaN
# column name : workplaces_lag4 - 0.1906180193596426 NaN
# column name : workplaces_lag5 - 0.19583023082650783 NaN
# column name : gathrecomany_lag1 - 0.006329113924050633 NaN
# column name : gathrecomany_lag2 - 0.012658227848101266 NaN
# column name : gathrecomany_lag3 - 0.0189873417721519 NaN
# column name : gathrecomany_lag4 - 0.02531645569620253 NaN
# column name : gathrecomany_lag5 - 0.03164556962025317 NaN
# column name : deaths_lag1 - 0.006329113924050633 NaN
# column name : deaths_lag2 - 0.012658227848101266 NaN
# column name : deaths_lag3 - 0.0189873417721519 NaN
# column name : deaths_lag4 - 0.02531645569620253 NaN
# column name : deaths_lag5 - 0.03164556962025317 NaN
# column name : transit_stations_pct1_lag1 - 0.18056589724497393 NaN
# column name : transit_stations_pct1_lag2 - 0.18664681062298338 NaN
# column name : transit_stations_pct1_lag3 - 0.192975924547034 NaN
# column name : transit_stations_pct1_lag4 - 0.19905683792504344 NaN
# column name : transit_stations_pct1_lag5 - 0.20513775130305287 NaN
# column name : cases_nom_pct5_lag1 - 0.30392156862745096 NaN
# column name : cases_nom_pct5_lag2 - 0.3102506825515016 NaN
# column name : cases_nom_pct5_lag3 - 0.31657979647555223 NaN
# column name : cases_nom_pct5_lag4 - 0.3229089103996029 NaN
# column name : cases_nom_pct5_lag5 - 0.3292380243236535 NaN
# column name : cases_nom_pct10_lag1 - 0.3355671382477041 NaN
# column name : cases_nom_pct10_lag2 - 0.3418962521717548 NaN
# column name : cases_nom_pct10_lag3 - 0.3482253660958054 NaN
# column name : cases_nom_pct10_lag4 - 0.35455448001985607 NaN
# column name : cases_nom_pct10_lag5 - 0.3608835939439067 NaN
# column name : cases_pct1_lag1 - 0.27860511293124846 NaN
# column name : cases_pct1_lag2 - 0.28493422685529907 NaN
# column name : cases_pct1_lag3 - 0.29126334077934973 NaN
# column name : cases_pct1_lag4 - 0.29759245470340034 NaN
# column name : cases_pct1_lag5 - 0.30392156862745096 NaN
# column name : retail_and_recreation_lag1 - 0.18168279970215934 NaN
# column name : retail_and_recreation_lag2 - 0.18428890543559195 NaN
# column name : retail_and_recreation_lag3 - 0.18801191362620998 NaN
# column name : retail_and_recreation_lag4 - 0.1906180193596426 NaN
# column name : retail_and_recreation_lag5 - 0.19583023082650783 NaN
# column name : residential_pct2_lag1 - 0.2315711094564408 NaN
# column name : residential_pct2_lag2 - 0.23790022338049144 NaN
# column name : residential_pct2_lag3 - 0.24410523703152148 NaN
# column name : residential_pct2_lag4 - 0.2504343509555721 NaN
# column name : residential_pct2_lag5 - 0.2565152643335815 NaN
# column name : deaths_pct2_lag1 - 0.3829734425415736 NaN
# column name : deaths_pct2_lag2 - 0.3893025564656242 NaN
# column name : deaths_pct2_lag3 - 0.39563167038967484 NaN
# column name : deaths_pct2_lag4 - 0.4019607843137255 NaN
# column name : deaths_pct2_lag5 - 0.4082898982377761 NaN
# column name : emergdec_lag1 - 0.006329113924050633 NaN
# column name : emergdec_lag2 - 0.012658227848101266 NaN
# column name : emergdec_lag3 - 0.0189873417721519 NaN
# column name : emergdec_lag4 - 0.02531645569620253 NaN
# column name : emergdec_lag5 - 0.03164556962025317 NaN
# column name : gathrestrict250_lag1 - 0.006329113924050633 NaN
# column name : gathrestrict250_lag2 - 0.012658227848101266 NaN
# column name : gathrestrict250_lag3 - 0.0189873417721519 NaN
# column name : gathrestrict250_lag4 - 0.02531645569620253 NaN
# column name : gathrestrict250_lag5 - 0.03164556962025317 NaN
# column name : restaurantrestrict_lag1 - 0.006329113924050633 NaN
# column name : restaurantrestrict_lag2 - 0.012658227848101266 NaN
# column name : restaurantrestrict_lag3 - 0.0189873417721519 NaN
# column name : restaurantrestrict_lag4 - 0.02531645569620253 NaN
# column name : restaurantrestrict_lag5 - 0.03164556962025317 NaN
# column name : caseisolation_lag1 - 0.006329113924050633 NaN
# column name : caseisolation_lag2 - 0.012658227848101266 NaN
# column name : caseisolation_lag3 - 0.0189873417721519 NaN
# column name : caseisolation_lag4 - 0.02531645569620253 NaN
# column name : caseisolation_lag5 - 0.03164556962025317 NaN
# column name : transit_stations_pct10_lag1 - 0.23591461901216182 NaN
# column name : transit_stations_pct10_lag2 - 0.24211963266319186 NaN
# column name : transit_stations_pct10_lag3 - 0.2484487465872425 NaN
# column name : transit_stations_pct10_lag4 - 0.25477786051129314 NaN
# column name : transit_stations_pct10_lag5 - 0.26110697443534375 NaN
# column name : transit_stations_pct5_lag1 - 0.20501365103003227 NaN
# column name : transit_stations_pct5_lag2 - 0.2113427649540829 NaN
# column name : transit_stations_pct5_lag3 - 0.21767187887813352 NaN
# column name : transit_stations_pct5_lag4 - 0.22387689252916357 NaN
# column name : transit_stations_pct5_lag5 - 0.2302060064532142 NaN
# column name : cases_pct5_lag1 - 0.30392156862745096 NaN
# column name : cases_pct5_lag2 - 0.3102506825515016 NaN
# column name : cases_pct5_lag3 - 0.31657979647555223 NaN
# column name : cases_pct5_lag4 - 0.3229089103996029 NaN
# column name : cases_pct5_lag5 - 0.3292380243236535 NaN
# column name : grocery_and_pharmacy_lag1 - 0.18168279970215934 NaN
# column name : grocery_and_pharmacy_lag2 - 0.18428890543559195 NaN
# column name : grocery_and_pharmacy_lag3 - 0.18801191362620998 NaN
# column name : grocery_and_pharmacy_lag4 - 0.1906180193596426 NaN
# column name : grocery_and_pharmacy_lag5 - 0.19583023082650783 NaN
# column name : workplaces_pct1_lag1 - 0.18106229833705634 NaN
# column name : workplaces_pct1_lag2 - 0.18739141226110698 NaN
# column name : workplaces_pct1_lag3 - 0.19372052618515762 NaN
# column name : workplaces_pct1_lag4 - 0.20004964010920823 NaN
# column name : workplaces_pct1_lag5 - 0.20637875403325887 NaN
# column name : grocery_and_pharmacy_pct10_lag1 - 0.2504343509555721 NaN
# column name : grocery_and_pharmacy_pct10_lag2 - 0.25601886324149914 NaN
# column name : grocery_and_pharmacy_pct10_lag3 - 0.26197567634648794 NaN
# column name : grocery_and_pharmacy_pct10_lag4 - 0.268180689997518 NaN
# column name : grocery_and_pharmacy_pct10_lag5 - 0.27413750310250684 NaN
# column name : deaths_nom_pct5_lag1 - 0.4019607843137255 NaN
# column name : deaths_nom_pct5_lag2 - 0.4082898982377761 NaN
# column name : deaths_nom_pct5_lag3 - 0.4146190121618268 NaN
# column name : deaths_nom_pct5_lag4 - 0.4209481260858774 NaN
# column name : deaths_nom_pct5_lag5 - 0.427277240009928 NaN
# column name : residential_pct5_lag1 - 0.2500620501365103 NaN
# column name : residential_pct5_lag2 - 0.2558947629684785 NaN
# column name : residential_pct5_lag3 - 0.2622238768925292 NaN
# column name : residential_pct5_lag4 - 0.2685529908165798 NaN
# column name : residential_pct5_lag5 - 0.27475800446760984 NaN
# column name : travelrestrictintra_lag1 - 0.006329113924050633 NaN
# column name : travelrestrictintra_lag2 - 0.012658227848101266 NaN
# column name : travelrestrictintra_lag3 - 0.0189873417721519 NaN
# column name : travelrestrictintra_lag4 - 0.02531645569620253 NaN
# column name : travelrestrictintra_lag5 - 0.03164556962025317 NaN
# column name : deaths_pct10_lag1 - 0.43360635393397867 NaN
# column name : deaths_pct10_lag2 - 0.4399354678580293 NaN
# column name : deaths_pct10_lag3 - 0.4462645817820799 NaN
# column name : deaths_pct10_lag4 - 0.45259369570613056 NaN
# column name : deaths_pct10_lag5 - 0.45892280963018117 NaN
# column name : retail_and_recreation_pct2_lag1 - 0.18230330106726234 NaN
# column name : retail_and_recreation_pct2_lag2 - 0.18838421444527179 NaN
# column name : retail_and_recreation_pct2_lag3 - 0.19471332836932242 NaN
# column name : retail_and_recreation_pct2_lag4 - 0.20079424174733185 NaN
# column name : retail_and_recreation_pct2_lag5 - 0.2071233556713825 NaN
# column name : gathrestrict5_lag1 - 0.006329113924050633 NaN
# column name : gathrestrict5_lag2 - 0.012658227848101266 NaN
# column name : gathrestrict5_lag3 - 0.0189873417721519 NaN
# column name : gathrestrict5_lag4 - 0.02531645569620253 NaN
# column name : gathrestrict5_lag5 - 0.03164556962025317 NaN
# column name : cases_lag1 - 0.006329113924050633 NaN
# column name : cases_lag2 - 0.012658227848101266 NaN
# column name : cases_lag3 - 0.0189873417721519 NaN
# column name : cases_lag4 - 0.02531645569620253 NaN
# column name : cases_lag5 - 0.03164556962025317 NaN
# column name : residential_lag1 - 0.18168279970215934 NaN
# column name : residential_lag2 - 0.18428890543559195 NaN
# column name : residential_lag3 - 0.18801191362620998 NaN
# column name : residential_lag4 - 0.1906180193596426 NaN
# column name : residential_lag5 - 0.19583023082650783 NaN
# column name : cases_nom_pct1_lag1 - 0.27860511293124846 NaN
# column name : cases_nom_pct1_lag2 - 0.28493422685529907 NaN
# column name : cases_nom_pct1_lag3 - 0.29126334077934973 NaN
# column name : cases_nom_pct1_lag4 - 0.29759245470340034 NaN
# column name : cases_nom_pct1_lag5 - 0.30392156862745096 NaN
# column name : gathrestrict25_lag1 - 0.006329113924050633 NaN
# column name : gathrestrict25_lag2 - 0.012658227848101266 NaN
# column name : gathrestrict25_lag3 - 0.0189873417721519 NaN
# column name : gathrestrict25_lag4 - 0.02531645569620253 NaN
# column name : gathrestrict25_lag5 - 0.03164556962025317 NaN
# column name : travelrestrictexit_lag1 - 0.006329113924050633 NaN
# column name : travelrestrictexit_lag2 - 0.012658227848101266 NaN
# column name : travelrestrictexit_lag3 - 0.0189873417721519 NaN
# column name : travelrestrictexit_lag4 - 0.02531645569620253 NaN
# column name : travelrestrictexit_lag5 - 0.03164556962025317 NaN
# column name : gathrestrict50_lag1 - 0.006329113924050633 NaN
# column name : gathrestrict50_lag2 - 0.012658227848101266 NaN
# column name : gathrestrict50_lag3 - 0.0189873417721519 NaN
# column name : gathrestrict50_lag4 - 0.02531645569620253 NaN
# column name : gathrestrict50_lag5 - 0.03164556962025317 NaN
# column name : gathrestrict3_lag1 - 0.006329113924050633 NaN
# column name : gathrestrict3_lag2 - 0.012658227848101266 NaN
# column name : gathrestrict3_lag3 - 0.0189873417721519 NaN
# column name : gathrestrict3_lag4 - 0.02531645569620253 NaN
# column name : gathrestrict3_lag5 - 0.03164556962025317 NaN
# column name : cases_pct10_lag1 - 0.3355671382477041 NaN
# column name : cases_pct10_lag2 - 0.3418962521717548 NaN
# column name : cases_pct10_lag3 - 0.3482253660958054 NaN
# column name : cases_pct10_lag4 - 0.35455448001985607 NaN
# column name : cases_pct10_lag5 - 0.3608835939439067 NaN
# column name : parks_pct2_lag1 - 0.17920079424174734 NaN
# column name : parks_pct2_lag2 - 0.18552990816579795 NaN
# column name : parks_pct2_lag3 - 0.1918590220898486 NaN
# column name : parks_pct2_lag4 - 0.19818813601389923 NaN
# column name : parks_pct2_lag5 - 0.20451724993794987 NaN
# column name : retail_and_recreation_pct10_lag1 - 0.23181931000248202 NaN
# column name : retail_and_recreation_pct10_lag2 - 0.23802432365351203 NaN
# column name : retail_and_recreation_pct10_lag3 - 0.24422933730454208 NaN
# column name : retail_and_recreation_pct10_lag4 - 0.2501861504095309 NaN
# column name : retail_and_recreation_pct10_lag5 - 0.25639116406056095 NaN
# column name : deaths_pct5_lag1 - 0.4019607843137255 NaN
# column name : deaths_pct5_lag2 - 0.4082898982377761 NaN
# column name : deaths_pct5_lag3 - 0.4146190121618268 NaN
# column name : deaths_pct5_lag4 - 0.4209481260858774 NaN
# column name : deaths_pct5_lag5 - 0.427277240009928 NaN
# 0.17099469886407445

# %%
df_ = []
days_avg = 3
col_keep = list(set(df.columns) - {'state', 'date'})
start_date = df.date.min()
end_date = df.date.max()

p_date = pd.date_range(start_date, end_date, freq="1D")

for state_name, group in df.groupby("state"):
    group_ = group.set_index("date").reindex(p_date)
    group_ = group_.resample("{}D".format(days_avg)).mean()
    group_["state"] = state_name
    df_.append(group_)
    
df = pd.concat(df_)
df.head()
# Out:
#             cases  deaths  population  emergdec  schoolclose  gathrestrict25  \
# 2020-01-22    0.0     0.0   4903185.0       0.0          0.0             0.0
# 2020-01-25    0.0     0.0   4903185.0       0.0          0.0             0.0
# 2020-01-28    0.0     0.0   4903185.0       0.0          0.0             0.0
# 2020-01-31    0.0     0.0   4903185.0       0.0          0.0             0.0
# 2020-02-03    0.0     0.0   4903185.0       0.0          0.0             0.0
#
#             gathrestrictany  otherbusinessclose  restaurantrestrict  \
# 2020-01-22              0.0                 0.0                 0.0
# 2020-01-25              0.0                 0.0                 0.0
# 2020-01-28              0.0                 0.0                 0.0
# 2020-01-31              0.0                 0.0                 0.0
# 2020-02-03              0.0                 0.0                 0.0
#
#             gathrestrict10  ...  retail_and_recreation_pct10_lag2  \
# 2020-01-22             0.0  ...                          0.233333
# 2020-01-25             0.0  ...                               NaN
# 2020-01-28             0.0  ...                               NaN
# 2020-01-31             0.0  ...                          0.560000
# 2020-02-03             0.0  ...                               NaN
#
#             retail_and_recreation_pct10_lag3  \
# 2020-01-22                          0.666667
# 2020-01-25                               NaN
# 2020-01-28                               NaN
# 2020-01-31                               NaN
# 2020-02-03                          0.560000
#
#             retail_and_recreation_pct10_lag4  \
# 2020-01-22                          0.464286
# 2020-01-25                               NaN
# 2020-01-28                               NaN
# 2020-01-31                               NaN
# 2020-02-03                          0.560000
#
#             retail_and_recreation_pct10_lag5  deaths_pct5_lag1  \
# 2020-01-22                          -0.09375               NaN
# 2020-01-25                               NaN               NaN
# 2020-01-28                               NaN               NaN
# 2020-01-31                               NaN          0.877551
# 2020-02-03                           0.56000               NaN
#
#             deaths_pct5_lag2  deaths_pct5_lag3  deaths_pct5_lag4  \
# 2020-01-22          0.814815          0.956522          3.400000
# 2020-01-25               NaN               NaN               NaN
# 2020-01-28               NaN               NaN               NaN
# 2020-01-31          0.877551               NaN               NaN
# 2020-02-03               NaN          0.877551          0.877551
#
#             deaths_pct5_lag5    state
# 2020-01-22          2.800000  Alabama
# 2020-01-25               NaN  Alabama
# 2020-01-28               NaN  Alabama
# 2020-01-31               NaN  Alabama
# 2020-02-03          0.877551  Alabama
#
# [5 rows x 440 columns]

# %%
target = "deaths"
df["target"] = df["{}_pct1".format(target)].shift(-1)
df.dropna(subset=["target"], inplace=True)
df = df.loc[:, df.isnull().mean() < 0.10].dropna()

y, data = np.log(1e-5+ df["target"]), df.loc[:, df.columns != "target"]
data.drop("state", axis=1, inplace=True)

# %%
from sklearn.model_selection import cross_val_score, train_test_split
x_train, x_test, y_train, y_test = train_test_split(data, 
                                                   y, 
                                                   train_size=0.8, 
                                                   shuffle=False, 
                                                   random_state=0)

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
# Out:
# Error in the Score specification: regression hinge
#  === Model Random_forest - TRAINING MODE ===
# TRAIN, TEST: SAMPLE 1 out of 5 - Random_forest / hinge
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 16.6min finished
# TRAIN, TEST: SAMPLE 2 out of 5 - Random_forest / hinge
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   52.2s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   52.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 18.1min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 21.5min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 21.6min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 21.7min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 22.5min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 24.7min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 25.1min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 25.1min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 25.2min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 25.2min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 25.2min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 25.2min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed: 25.4min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed: 25.4min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed: 25.6min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed: 25.7min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed: 26.0min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed: 26.0min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed: 26.0min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 26.1min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed: 26.1min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed: 27.7min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed: 27.7min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed: 32.9min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed: 33.2min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed: 33.4min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed: 33.6min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed: 33.8min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed: 33.9min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed: 33.9min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed: 33.9min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed: 34.0min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed: 34.0min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed: 34.0min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed: 34.1min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed: 34.3min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed: 34.4min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed: 34.4min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed: 34.6min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed: 34.6min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed: 34.9min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed: 35.4min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed: 35.4min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed: 35.7min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed: 36.3min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 49.6min finished
# TRAIN, TEST: SAMPLE 3 out of 5 - Random_forest / hinge
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   51.0s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 12.9min finished
# TRAIN, TEST: SAMPLE 4 out of 5 - Random_forest / hinge
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 18.1min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 18.4min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 25.1min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 25.3min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed: 25.4min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed: 25.8min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed: 26.2min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed: 26.3min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed: 26.4min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed: 26.4min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed: 26.5min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed: 26.5min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 26.6min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed: 26.6min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed: 26.7min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed: 27.7min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed: 27.7min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed: 27.9min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed: 28.0min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed: 28.2min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed: 28.4min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed: 28.5min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed: 28.7min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed: 28.9min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed: 28.9min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed: 29.1min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed: 29.2min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed: 29.3min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed: 29.4min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed: 29.4min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed: 29.5min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed: 29.5min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed: 29.5min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed: 29.6min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed: 29.7min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed: 30.0min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed: 30.1min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed: 30.1min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed: 30.2min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed: 30.2min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed: 30.2min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed: 30.3min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed: 30.3min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed: 30.4min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 31.6min finished
# TRAIN, TEST: SAMPLE 5 out of 5 - Random_forest / hinge
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed: 22.5min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed: 22.6min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed: 22.6min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed: 22.6min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed: 22.6min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed: 22.7min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed: 22.7min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed: 22.7min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed: 22.7min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed: 23.0min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed: 23.0min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed: 23.1min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed: 24.0min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed: 24.2min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed: 24.2min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed: 24.4min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 27.6min finished
# TRAINING : DONE - Random_forest
# mean score out of sample: 0.6901377242978586

# %%
hparams =  {
            "C": np.logspace(-3, 0., 50),
            "fit_intercept": [True, False],
            "class_weight": ["balanced"],
            "max_iter": list(range(20, 50)),
            "solver": ["liblinear", "sag"]
            }

# %%
# scaling
scaler = StandardScaler()
row_names = x_train.index
x_train_sc = pd.DataFrame(data=scaler.fit_transform(X_train), index=row_names)
x_val_sc = scaler.transform(X_val)

# create the model
rclf = RandomizedSearchCV(estimator=Lasso(),
                          param_distributions=hparams,
                          verbose=15, n_iter=100,
                          n_jobs=3,
                          random_state=1234)

rclf.fit(iris.data, iris.target)
mclf.fit(x_train_sc)

# %%
import pickle

# %%
with open("save.pkl", "wb") as file:
    pickle.dump(feature_selection, file)

# %%
feature_selection.feature_importance
# Out:
#                   Variable  Importance
# 32               cases_nom  100.000000
# 33              deaths_nom   45.554081
# 59          cases_nom_pct2   27.693672
# 86              cases_pct2   20.330825
# 87              cases_pct5   12.845491
# ..                     ...         ...
# 303  gathrestrict1000_lag1    0.000000
# 302    home_time_pct2_lag5    0.000000
# 301    home_time_pct2_lag4    0.000000
# 300    home_time_pct2_lag3    0.000000
# 558         cases_nom_lag5    0.000000
#
# [559 rows x 2 columns]

# %%
np.log(1e-6+ y).hist(bins=300)

# %%
y, data = np.log(1e-5+ df["target"]), df.loc[:, df.columns != "target"]
data = data
data.drop("state", axis=1, inplace=True)

# %%
feature_selection.get_best_features(.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf4dccf81012> in <module>
# ----> 1 feature_selection.get_best_features(.5)
#
# NameError: name 'feature_selection' is not defined

# %%
y.hist(bins=1000)
